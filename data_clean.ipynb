# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c149c7fe-d5a9-4501-b837-a1ce966669c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c149c7fe-d5a9-4501-b837-a1ce966669c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
zip_path = '/content/e88186124ec611f1.zip'
extract_to = '/content/gridlock_dataset'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("Extraction complete.")
# Out:
# Extraction complete.

# %%
import pandas as pd

df = pd.read_csv('/content/gridlock_dataset/dataset/train.csv')
df.head()
# Out:
#    Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 0      0  qp02z1   48       0:0  0.048804          NaN              1
# 1      1  qp02zt   48       0:0  0.118507  Residential              3
# 2      2  qp08bj   48       0:0  0.027132  Residential              1
# 3      3  qp08gt   48       0:0  0.003272  Residential              1
# 4      4  qp02zq   48       0:0  0.010819  Residential              1
#
#   LargeVehicles Landmarks  Temperature Weather
# 0   Not Allowed        No          NaN     NaN
# 1       Allowed       Yes    31.104565   Sunny
# 2   Not Allowed        No    25.919267   Sunny
# 3   Not Allowed        No          NaN   Rainy
# 4   Not Allowed        No    10.803667   Rainy

# %%
print(df.isnull().sum())
# Out:
# Index               0
# geohash             0
# day                 0
# timestamp           0
# demand              0
# RoadType          600
# NumberofLanes       0
# LargeVehicles       0
# Landmarks           0
# Temperature      2495
# Weather           797
# dtype: int64

# %%
df_cleaned = df.dropna()
df_encoded = pd.get_dummies(df_cleaned, columns=['Weather'], prefix='Weather')
df_encoded.dropna(subset=['Temperature'], inplace=True)

# %%
df_encoded
# Out:
#        Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 1          1  qp02zt   48       0:0  0.118507  Residential              3
# 2          2  qp08bj   48       0:0  0.027132  Residential              1
# 4          4  qp02zq   48       0:0  0.010819  Residential              1
# 5          5  qp02zw   48       0:0  0.016262  Residential              2
# 6          6  qp02zy   48       0:0  0.042247  Residential              3
# ...      ...     ...  ...       ...       ...          ...            ...
# 77294  77294  qp0d4n   49       2:0  0.067203  Residential              1
# 77295  77295  qp0d4q   49       2:0  0.022859  Residential              3
# 77296  77296  qp0d4w   49       2:0  0.141342  Residential              3
# 77297  77297  qp0dhw   49       2:0  0.087574  Residential              1
# 77298  77298  qp0djq   49       2:0  0.002944  Residential              3
#
#       LargeVehicles Landmarks  Temperature  Weather_Foggy  Weather_Rainy  \
# ...

# %%
df_encoded = pd.get_dummies(df_encoded, columns=['RoadType'], prefix='Road')

# %%
df_encoded.head()
# Out:
#    Index geohash  day timestamp    demand  NumberofLanes LargeVehicles  \
# 1      1  qp02zt   48       0:0  0.118507              3       Allowed
# 2      2  qp08bj   48       0:0  0.027132              1   Not Allowed
# 4      4  qp02zq   48       0:0  0.010819              1   Not Allowed
# 5      5  qp02zw   48       0:0  0.016262              2   Not Allowed
# 6      6  qp02zy   48       0:0  0.042247              3       Allowed
#
#   Landmarks  Temperature  Weather_Foggy  Weather_Rainy  Weather_Snowy  \
# 1       Yes    31.104565          False          False          False
# 2        No    25.919267          False          False          False
# 4        No    10.803667          False           True          False
# 5       Yes     8.446025          False           True          False
# 6       Yes    15.772408           True          False          False
#
#    Weather_Sunny  Road_Highway  Road_Residential  Road_Street
# ...

# %%
df_encoded['LargeVehicles'] = df_encoded['LargeVehicles'].map({'Allowed' : 1, 'Not Allowed' : 0})
# Out:
# Index                  21760
# geohash               qp09hm
# day                       48
# timestamp               6:15
# demand                0.0762
# NumberofLanes              3
# LargeVehicles            NaN
# Landmarks                Yes
# Temperature         17.37816
# Weather_Foggy           True
# Weather_Rainy          False
# Weather_Snowy          False
# Weather_Sunny          False
# Road_Highway           False
# Road_Residential        True
# Road_Street            False
# Name: 21760, dtype: object
